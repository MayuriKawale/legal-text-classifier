# %%
# !git clone https://github.com/MayuriKawale/legal-text-classifier.git
# %cd legal-text-classifier
# Out:
# Cloning into 'legal-text-classifier'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 109 (delta 49), reused 98 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 111.19 KiB | 7.41 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# /content/legal-text-classifier

# %%
# Check if GPU is available
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
print(f"Device Name: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU only'}")
# Out:
# GPU Available: True
# Device Name: Tesla T4

# %%
# Install dependencies
# !pip install transformers datasets scikit-learn torch evaluate accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.8 MB/s eta 0:00:00
# ...

# %%
# Verify everything is installed correctly
import torch
import transformers
import datasets
import sklearn
print(f"torch version:         {torch.__version__}")
print(f"transformers version:  {transformers.__version__}")
print(f"datasets version:      {datasets.__version__}")
print(f"sklearn version:       {sklearn.__version__}")
print(f"GPU Available:         {torch.cuda.is_available()}")
# Out:
# torch version:         2.10.0+cu128
# transformers version:  5.0.0
# datasets version:      4.0.0
# sklearn version:       1.6.1
# GPU Available:         True

# %%
# Run in debug mode before full training
# !python main.py --mode train --debug
# Out:
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 226kB/s]
# vocab.txt: 232kB [00:00, 7.14MB/s]
# tokenizer.json: 466kB [00:00, 3.88MB/s]
# ...
# README.md: 34.1kB [00:00, 75.1MB/s]
# ecthr_a/train-00000-of-00001.parquet: 100% 42.4M/42.4M [00:01<00:00, 30.4MB/s]
# ecthr_a/test-00000-of-00001.parquet: 100% 5.68M/5.68M [00:00<00:00, 6.70MB/s]
# ecthr_a/validation-00000-of-00001.parque(…): 100% 5.26M/5.26M [00:00<00:00, 9.80MB/s]
# Generating train split: 100% 9000/9000 [00:00<00:00, 22724.60 examples/s]
# Generating test split: 100% 1000/1000 [00:00<00:00, 22595.58 examples/s]
# Generating validation split: 100% 1000/1000 [00:00<00:00, 15609.44 examples/s]
# config.json: 100% 483/483 [00:00<00:00, 2.32MB/s]
# model.safetensors: 100% 268M/268M [00:02<00:00, 113MB/s]
# Loading weights: 100% 100/100 [00:00<00:00, 965.80it/s, Materializing param=distilbert.transformer.layer.5.sa_layer_norm.weight]
# DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# ...

# %%
# Run full training
# !python main.py --mode train
# Out:
# Loading weights: 100% 100/100 [00:00<00:00, 2049.58it/s, Materializing param=distilbert.transformer.layer.5.sa_layer_norm.weight]
# DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_transform.bias    | UNEXPECTED |
# vocab_projector.bias    | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# classifier.weight       | MISSING    |
# pre_classifier.bias     | MISSING    |
# classifier.bias         | MISSING    |
# pre_classifier.weight   | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Used device: cuda
# Epoch 1/3, Batch 100/1125, Loss: 0.2704
# ...

# %%
# Run Evaluation
# !python main.py --mode evaluate
# Out:
# Loading weights: 100% 104/104 [00:00<00:00, 2145.21it/s, Materializing param=pre_classifier.weight]
# Running evaluation on the test set...
# ...
# Overall Metrics:
# ...
# Micro F1 Score: 0.6393
# Macro F1 Score: 0.5054
# Weighted F1 Score: 0.6227
# ...
#
# Per Label F1 Scores:
# ...
# Article    2 | ████████████████████████████████████ | F1 Score: 0.7324
# Article    3 | ██████████████████████████████████ | F1 Score: 0.6980
# Article    5 | ██████████████████████████████████ | F1 Score: 0.6854
# Article    6 | ███████████████████████████████ | F1 Score: 0.6214
# Article    8 | ██████████████████████ | F1 Score: 0.4444
# Article    9 |                      | F1 Score: 0.0000
# Article   10 | ██████████████████████████ | F1 Score: 0.5354
# Article   11 | ████████████████████████ | F1 Score: 0.4815
# Article   14 | █████                | F1 Score: 0.1111
# Article P1-1 | █████████████████████████████████████ | F1 Score: 0.7442

# %%
# Run Inference
# !python main.py --mode inference --text "The applicant was detained for 14 months without being brought before a judge. His requests for release were repeatedly denied without explanation. The domestic courts failed to provide adequate reasoning for continued detention."
# Out:
# Loading weights: 100% 104/104 [00:00<00:00, 1641.74it/s, Materializing param=pre_classifier.weight]
# ...
# Predicted Article Violations
# ...
# Article    5 | ██████████████████   | Probability: 0.9488
#              Right to liberty and security

# %%
# Download the model
import shutil
from google.colab import files

# Zip the models folder
shutil.make_archive("/content/legal-text-classifier/models", "zip", "/content/legal-text-classifier/models")

# Download the zip
files.download("/content/legal-text-classifier/models.zip")
